# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
import pickle

# %%
# !pip install scikeras
# Out:
# Requirement already satisfied: scikeras in .\venv\Lib\site-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from scikeras) (3.15.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from scikeras) (1.9.0)
# Requirement already satisfied: absl-py in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from keras>=3.2.0->scikeras) (2.5.0)
# Requirement already satisfied: numpy in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from keras>=3.2.0->scikeras) (2.4.6)
# Requirement already satisfied: rich in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from keras>=3.2.0->scikeras) (15.0.0)
# Requirement already satisfied: namex in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from keras>=3.2.0->scikeras) (3.14.0)
# Requirement already satisfied: optree in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from keras>=3.2.0->scikeras) (0.19.1)
# Requirement already satisfied: ml-dtypes in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from keras>=3.2.0->scikeras) (0.5.4)
# Requirement already satisfied: packaging in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from keras>=3.2.0->scikeras) (26.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from scikit-learn>=1.4.2->scikeras) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from scikit-learn>=1.4.2->scikeras) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from scikit-learn>=1.4.2->scikeras) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from optree->keras>=3.2.0->scikeras) (4.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from rich->keras>=3.2.0->scikeras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from rich->keras>=3.2.0->scikeras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
data=pd.read_csv('Churn_Modelling.csv')
data = data.drop(['RowNumber','CustomerId', 'Surname'], axis=1)

label_encoder_gender=LabelEncoder()
data['Gender']=label_encoder_gender.fit_transform(data['Gender'])

onehot_encoder_geo=OneHotEncoder(handle_unknown='ignore')
geo_encoded=onehot_encoder_geo.fit_transform(data[['Geography']]).toarray()
geo_encoded_df=pd.DataFrame(geo_encoded, columns=onehot_encoder_geo.get_feature_names_out(['Geography']))

data=pd.concat([data.drop('Geography', axis=1), geo_encoded_df], axis=1)

x = data.drop('Exited', axis=1)
y = data['Exited']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

scaler=StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

## save the encoders and sca-learn
with open('label_encoder_gender.pkl','wb') as file:
    pickle.dump(label_encoder_gender,file)
    
with open('onehot_encoder_geo.pkl','wb') as file:
    pickle.dump(onehot_encoder_geo,file)
    
with open('scaler.pkl','wb') as file:
    pickle.dump(scaler,file)

# %%
# Define model builder
def create_model(neurons=32, layers=1):
    model = Sequential()
    model.add(Dense(neurons, activation='relu', input_shape=(x_train.shape[1],)))
    for _ in range(layers - 1):
        model.add(Dense(neurons, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss="binary_crossentropy", metrics=['accuracy'])
    return model

# %%
# Wrap with SciKeras
model = KerasClassifier(model=create_model, epochs=50, batch_size=10, verbose=0)

# %%
# Define grid search parameters
param_grid = {
    "model__neurons": [16, 32, 64, 128],
    "model__layers": [1, 2, 3],
    "batch_size": [10, 20],
    "epochs": [50, 100]
}

# %%
# Perform grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3, verbose=1)
grid_result = grid.fit(x_train, y_train)

# Print the best parameters
print(f"Best: {grid_result.best_score_:.4f} using {grid_result.best_params_}")
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
